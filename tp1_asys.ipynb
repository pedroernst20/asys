# %% [markdown]
# <a href="https://colab.research.google.com/github/pedroernst20/asys/blob/main/tp1_asys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# #**TRABAJO PRÁCTICO 1**
# * Integrantes:
#   * Pedro Ernst (Leg. 400624 - DNI 45692616)
#   * Cabaleiro Martín (Leg. 404821  DNI 46129874)
#   * Maudown
#   * Perea Ignacio (Leg. 406265 - DNI 46543115)
#   * Gatica Marcos Raúl (Leg. 402006 - DNI 45091292)
# * Curso:
#   * 2R1
# * Asignatura:
#   * Análisis de Señales y Sistemas.
# * Profesores a cargo:
#   * Fredderic
#   * La otra mina
#
# ---

# %% [markdown]
# # ***Ejercicio 1.***
# ## ***Marco teorico usado***
# Para transformar un numero complejo entre sus distintas representaciones (coordenada, binomial, polar y exponencial), es necesario conocer las relaciones fundamentales entre ellas.
#
# Un número complejo en el plano puede representarse como un par ordenado
# (𝑥, 𝑦), donde 𝑥 es la parte real y 𝑦 la parte imaginaria. Esta representación es equivalente a su forma **binomial**
# $$
# z = x +jy
# $$
#
# Para expresar un numero en su forma **polar** , se debe calcular el modulo *'r'* y su argumento *'θ'* del mismo numero complejo, el modulo se obtiene aplicando el conocido teorema de pitagoras
# $$
# r = |z| = \sqrt{x^2+y^2}
# $$
# Y para obtener el argumento se obtiene con la funcion arcotangente
# $$
# \theta = arg(z) = arctan (\dfrac{y}{x})
# $$
# Entonces recopilando todo un numero en su representacion **polar** se podria escribir como
# $$
# z = (r, \theta)
# $$
#
# Ahora para expresar su forma **exponencial** usamos la formula de euler, se expresa como
# $$
# z = r e^{j\theta}
# $$

# %% [markdown]
# Ejercicio 1. Considerar la siguiente tabla de números complejos.
# * Actividad 1.1. Completar la table con todas las representaciones faltantes.
#
# \begin{array}{|c|c|c|c|c|} \hline
# Representación & Par\ Ordenado:\ (x,y) & Binomial:\ (x+yj) & Polar:\ (|z|,∠z) & Exp:\ |z| e^{(∠z)j}\\ \hline
# z_1= & (3,2) &3+2j & (\sqrt{13},\dfrac{9\pi}{50})& \sqrt{13}\,e^{\dfrac{9\pi}{50}j} \\ \hline
# z_2= & (\sqrt{2},\sqrt{2}) & \sqrt{2}+\sqrt{2}j & \Big(2,\dfrac{\pi}{4}\Big) &2e^{\dfrac{\pi}{4}j} \\ \hline
# z_3= & (2,-1) & 2-1j & (\sqrt{5},-\dfrac{\pi}{7}) & \sqrt{5}\,e^{-\dfrac{\pi}{7}j}\\ \hline\\
# z_4= & (5,-2) & 5-2j & (\sqrt{29};5,9) & \sqrt{29}e^{5,9j} \\ \hline
# z_5= & (4\sqrt{3},-4) & 4\sqrt{3}\,-4j & (8,{-\dfrac{\pi}{6}}) & 8\,e^{(-\dfrac{\pi}{6})\,j} \\ \hline
# z_6= & (\sqrt{2},-\sqrt{2}) & \sqrt{2}-\sqrt{2} & \Big(2,-\dfrac{\pi}{4}\Big ) & 2\,e^{(-\dfrac{\pi}{4})\,j} \\ \hline
# z_7= & \Big (-2,\dfrac{\pi}{4}\Big) & -2+\dfrac{\pi}{4}j & (2,14,\dfrac{22\pi}{25}) & 2,14\,e^{\dfrac{22\pi}{25}j} \\ \hline
# z_8= & (\dfrac{1}{2},-\dfrac{\sqrt{3}}{2}) & -\dfrac{1}{2}-j \dfrac{\sqrt{3}}{2}  & (1,-\dfrac{\pi}{3}) & e^{-\dfrac{\pi}{3}j} \\ \hline
# z_9= & (-\dfrac{32}{25}, - \dfrac{141}{50}) & -\dfrac{32}{25} - \dfrac{141}{50}j & (\pi, -2) & \pi\,e^{(-2)\,j} \\ \hline
# z_{10}= & (5,5\sqrt{3}) & 5+5\sqrt{3} & \Big(10,\dfrac{\pi}{3}\Big) & 10e^{\dfrac{\pi}{3}j} \\ \hline
# \end{array}
#
#
# * Actividad 1.2. Realizar el grafico discreto de los modulos para la secuencia de los diez números complejos de la tabla, esto es, $\{(n,|z_n|): n = 1,...10\}$.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "n": np.arange(1, 11),
    "modulo": [np.sqrt(13), 2, np.sqrt(5), np.sqrt(29), 8, 2, 2.14, 1, np.pi, 10]
}

df = pd.DataFrame(data)

plt.vlines(df["n"], ymin=0, ymax=df["modulo"], color="blue", alpha=0.8, linewidth=2)
plt.scatter(df["n"], df["modulo"], color="blue", marker="o")

plt.xlabel("n")
plt.ylabel("|z|")
plt.title("Gráfico discreto de los módulos de z (|z|)")
plt.xticks(df["n"])
plt.yticks(np.arange(0, 12, 1))
plt.grid(True, linestyle="--", alpha=0.6)

# %% [markdown]
# * Actividad 1.3. Realizar el grafico discreto de las fases para la secuencia de los diez números complejos de la tabla, esto es, $\{(n,∠(z_n)): n = 1,...10\}$.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "n": np.arange(1, 11),
    "argumento": [9*np.pi/50, np.pi/4, -np.pi/7, 1.87*np.pi, -np.pi/6, -np.pi/4, 0.88*np.pi, -np.pi/3, -2, np.pi/3]
}

df = pd.DataFrame(data)

plt.vlines(df["n"], ymin=-3, ymax=df["argumento"], color="blue", alpha=0.8, linewidth=2)
plt.scatter(df["n"], df["argumento"], color="blue", marker="o")

plt.xlabel("n")
plt.ylabel(r"$\theta$ (radianes)")
plt.title(r"Gráfico discreto de los argumentos de z ($\theta$)")
plt.xticks(df["n"])
plt.yticks(np.arange(-3, 8, 1))
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %% [markdown]
# # ***Ejercicio 2.***
# ##**Marco teorico utilizado**
# Una funcion compleja siempre se va a poder expresar en terminos de
# $$
# f(z) = f(x + iy) = u(x, y) + iv(x, y)
# $$
# $$\text{donde} \space u(x, y) \space \text{es la parte real de la funcion}$$
# $$\text{donde} \space v(x, y) \space \text{es la parte imaginaria de la funcion}$$
#
# ##  Ejercicio 2. Considerar el mapeo de variable compleja ω = $z^2$
# Ejercicio 2.1
# Obtener la parte real e imaginaria de la variable $ω = u_{(x;y)} + jv_{(x;y)}$
#
# <u> Resolución </u> \\
# Encontrar la parte real e imaginaria de $ω$: \\
# * $Re(ω) = U_{(x;y)}$ **Incógnita**
# * $Imag(ω) = V_{(x;y)}$ **Incógnita**
#
# Suponiendo $z$ expresado en rectángular / binomial:  <div align="center"> $z = x + jv$ </div>
# Se pasará esta expresión a la función mapeo $w$: \\
# <div align="center">
# ⇒  $ω = z^2$ <br>
# $ω = (x+jv)^2$ <br>
# $ω = x^2 + 2xyj - y^2$ <br>
# <mark>$ω = (x^2-y^2) + 2xyj$ </mark> <br>
# </div>
#
# Resumiendo: <br>
# * $Re(ω) = U_{(x;y)}$ = $x^2 - y^2$ <br>
# * $Imag(ω) = V_{(x;y)}$ = $2xy$
#
# Ejercicio 2.2 demostrar que el mapeo propuesto es una función analítica en todo el plano complejo, empleando para ello dos métodos distintos:
# * **Método 1:** Usando la definición de los límites incrementales, esto es
# <div align="center">
# $$
# \lim_{\Delta z \to 0} \frac{\Delta ω}{\Delta z}
# $$
# </div>
# <u> Resolución: </u>
# $$
# \lim_{\Delta z \to 0} \frac{\Delta \omega}{\Delta z} = \lim_{\Delta z \to 0}\frac{f_{(z + \Delta z)} - f_{z}}{\Delta z}
# $$ <br>
#
#
# Se procede a expandir el numerador:
# $$ f(z + \Delta z) - f(z) = (z + \Delta z)^2 - z^2 $$
#
# $$ \require{cancel} f(z + \Delta z) - f(z) =  \cancel{ z^2 } + 2z \Delta z + \Delta z^2 -\cancel{ z^2 } $$
#
#  <mark>  $$ f(z + \Delta z) - f(z) = 2z\Delta z + \Delta z^2 $$ </mark>
# Volviendo al límite:
# $$
# \lim_{\Delta z \to 0} \frac{2z\Delta z + \Delta z^2}{\Delta z}
# $$
# $$
# = \require{cancel} \lim_{\Delta z \to 0} \frac{\cancel{\Delta z}(2z + \Delta z)}{\cancel{\Delta z}}
# $$
# $$ = \lim_{\Delta z \to 0} 2z + \Delta z $$  <div align="center"><mark> ⇒ 2z </mark></div>
# Se puede concluir que, al existir el límite y no depende de $\Delta z$, para todo $ω = z^2$ es analítica en todo el plano $\mathbb{C}$.
# * **Método 2:** Verificar que las funciones $u_{(x;y)}$ y $v_{(x;y)}$ cumples las ecuaciones de Cauchy-Riemann en todo el plano.
#
# <u> Resolución: </u> <br>
# Ecuaciones de Cauchy-Riemann (condición de analiticidad):
# $$
# \frac{∂u}{\partial x} = \frac{∂v}{\partial y} \land \frac{∂u}{\partial y} = - \frac{∂v}{\partial x}
# $$ <br>
# * $U_{(x;y)} = x^2 - y^2:$
# $$
# \frac{∂u}{\partial x} = 2x
# $$ <br>
# $$
# \frac{∂u}{\partial y} = -2y
# $$
#
# * $V_{(x;y)} =  2xy:$
# $$
# \frac{∂y}{\partial x} = 2y
# $$ <br>
# $$
# \frac{∂y}{\partial y} = 2x
# $$
#
# Entonces:
#
# $$
# \frac{∂u}{\partial x} = \frac{∂v}{\partial y}
# $$ <br>
# $$
# 2x = 2x \checkmark
# $$ <br>
# $$
# \frac{∂u}{\partial y} = \frac{∂v}{\partial x}
# $$ <br>
# $$
# -2y = 2y\checkmark
# $$ <br>
# Como cumple las ecuaciones de Cauchy-Riemann, la $\omega = z^2$ es analítica en todo el plano $\mathbb{C}$.
#
# ##Ejercicio 2.3##
# Se definen de forma analítica y parametrizada las sigueintes curvas en el plano complejo $\mathbb{Z}:$
# $$C_1 : z = tj \qquad -2 \leq t \leq 0$$ $$C_2 : z = t + tj \qquad 0 \leq t \leq 2$$ $$C_3 : z = (2-t) + 2j \qquad 0 \leq t \leq 2 $$
#
# * **Graficar las tres curvas en el plano complejo $\mathbb{Z}$**
#
# <u> Respuesta: </u> <br>
# Notése que las curvas son totalmente posibles de graficar en el plano complejo $\mathbb{C}$. Dado a que el ejercicio detalla que se usará el plano $\mathbb{Z}$, es posible hacerlo si extraemos la parte real e imaginaria de cada curva:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

t1 = np.linspace(-2, 0, 100)
z1 = 1j * t1
df1 = pd.DataFrame({'Re':z1.real, 'Imag': z1.imag, 'Curve': 'C1'})

t2 = np.linspace(0, 2, 100)
z2 = t2 + 1j * t2
df2 = pd.DataFrame({'Re':z2.real, 'Imag': z2.imag, 'Curve': 'C2'})

t3 = np.linspace(0, 2, 100)
z3 = (2 - t3) + 2j
df3 = pd.DataFrame({'Re':z3.real, 'Imag': z3.imag, 'Curve': 'C3'})

df = pd.concat([df1, df2, df3])

plt.figure(figsize=(7, 7))
for curve, color in zip(['C1', 'C2', 'C3'], ['blue', 'red', 'green']):
  subDf = df[df['Curve'] == curve]
  plt.plot(subDf['Re'], subDf['Imag'], label=f'{curve}', color=color, linewidth=2)

def flecha(x, y, dx, dy, **kwargs):
  plt.arrow(x, y, dx, dy, head_width=0.1, head_length=0.1, length_includes_head=True, **kwargs)

flecha(0, -1.5, 0, 0.5, color='blue')
flecha(0.8, 0.8, 0.5, 0.5, color='red')
flecha(1.2, 2, -0.5, 0, color='green')

plt.axhline(0, color='black', linewidth=0.8)
plt.axvline(0, color='black', linewidth=0.8)
plt.xlabel('Re($z$)', fontsize=12)
plt.ylabel('Imag($z$)', fontsize=12)
plt.title('Curvas en el plano complejo $\\mathbb{Z}$', fontsize=14)
plt.legend()
plt.grid()
plt.axis('equal')
# Out:
# (np.float64(-0.1525),
#  np.float64(2.1025),
#  np.float64(-2.2025),
#  np.float64(2.2525))

# %% [markdown]
# * **Obtener la expresión analítica y parametrizada de cada una de las curvas $C\prime_1$, $C\prime_2$, $C\prime_3$ en el plano $\mathcal{W}$, mapeando $C_1$, $C_2$ y $C_3$ respectivamente.**
#
# <u> Respuesta: </u> <br>
# Recordar la función que mapea:
# $$ \omega = f(z) = z^2$$
# * Mapeo de la curva $C_1$:
# $$
# z_{1(t)} = jt, -2 \leq t \leq 0
# $$ <br>
# $$
# w_{1(t)} = (z_{1(t)})^2
# $$
# $$
# w_{1(t)} = -t^2
# $$
# Parametrización:
# $$
# \omega_{1(t)} = -t^2 \qquad t \in [-2, 0]
# $$ <div align="center"> ------------------ </div>
# * Mapeo de la curva $C_2$:
# $$
# z_{2(t)} = t + jt, 0 \leq t \leq 2
# $$<br>
# $$
# w_{2(t)} = (t + jt)^2
# $$
# $$
# w_{2(t)} = t^2(1+j)^2
# $$
# $$
# w_{2(t)} = 2jt^2
# $$
# Parametrización:
# $$
# w_{2(t)} = 2jt^2 \qquad t \in [0, 2]
# $$
# <div align="center"> ------------------ </div>
# * Mapeo de la curva $C_3$:
# $$
# z_{3(t)} = (2 - t) + 2j \qquad 0 \leq t \leq 2
# $$ <br>
# $$
# w_{3(t)} = [(2 - t) +2j ]^2
# $$
# $$
# w_{3(t)} = (2-t)^2 + 4j(2-t) + (2j)^2
# $$
# $$
# w_{3(t)} = (2-t)(2-t+4j) -4
# $$
# $$
# \require{cancel}w_{3(t)} = \cancel{4}-2t+8j-2t+t^2-4jt\cancel{-4}
# $$
# $$
# w_{3(t)} = -4t+t^2+(8-t)j
# $$
# $$
# w_{3(t)} = (t^2-4t)+(8-4t)j
# $$
#
# Parametrización:
# $$
# w_{3(t)} = (t^2-4t)+(8-4t)j \qquad t \in [0,2]
# $$
# <div align="center"> ------------------ </div>
# *  Resumen:
# $$
# C\prime_1 = w_{1(t)} = -t^2 \qquad t\in[-2,0]
# $$
# $$
# C\prime_2 = w_{2(t)} = 2jt^2 \qquad t \in [0, 2]
# $$
# $$
# C\prime_3 = w_{3(t)} = (t^2-4t)+(8-4t)j \qquad t \in [0,2]
# $$<br>
#
# * **Graficar las tres curvas $C\prime_1$, $C\prime_2$ y $C\prime_3$ en el plano complejo $\mathcal{W}$**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

t1 = np.linspace(-2, 0, 100)
t2 = np.linspace(0, 2, 100)
t3 = np.linspace(0, 2, 100)

w1 = -t1**2
w2 = 2j * t2**2
w3 = (2 - t3 + 2j)**2

df1 = pd.DataFrame({'Re': w1.real, 'Im': w1.imag, 'Curve': "C1'"})
df2 = pd.DataFrame({'Re': w2.real, 'Im': w2.imag, 'Curve': "C2'"})
df3 = pd.DataFrame({'Re': w3.real, 'Im': w3.imag, 'Curve': "C3'"})

df = pd.concat([df1, df2, df3])

plt.figure(figsize=(7, 7))
for curve, color in zip(["C1'", "C2'", "C3'"], ['blue', 'red', 'green']):
    sub_df = df[df['Curve'] == curve]
    label_map = {
        "C1'": r"$C_1':\, w = -t^2$",
        "C2'": r"$C_2':\, w = 2j\,t^2$",
        "C3'": r"$C_3':\, w = (2 - t + 2j)^2$"
    }
    plt.plot(sub_df['Re'], sub_df['Im'], label=label_map[curve], linewidth=2, color=color)


plt.axhline(0, linewidth=0.5)
plt.axvline(0, linewidth=0.5)
plt.grid(True, linestyle='--', alpha=0.5)
plt.axis('equal')
plt.xlabel(r"Re$(w)$")
plt.ylabel(r"Imag$(w)$")
plt.title(r"Imágenes de $C_1^I, C_2^I, C_3^I$ bajo $w=z^2$ en el plano $\mathcal{W}$")
plt.legend()

# %% [markdown]
# # **Ejercicio 3**
#
# Considerar las funciones de variable compleja
# $$f(z) = cos(z), \qquad g(z)  = \dfrac{z^2 - cos(z)}{z^3}$$
#
# * Marco teórico utilizado:
# $$ cos(z) = \sum_{n=0}^{\infty} \frac{(-1)^n z^{2n}}{(2n)!} \Rightarrow \text{Serie de Taylor} $$
#
# $$ f(z) = \sum_{n=-\infty}^{\infty} a_k(z-z_0)^n \Rightarrow \text{Serie de Laurent} $$
#
# $$ a_n = \frac{1}{2\pi j}\displaystyle \oint_{C}\dfrac{f(z)}{(z-z_0)^{n+1}}\,dz $$
#
# $$ Res(f(z),z_0)=\dfrac{1}{(n-1)!}\lim_{z \to z_0} \dfrac{d^{n-1}}{dz^{n-1}}[(z - z_0)^n f(z)] $$
#
# * Actividad 3.1. Desarrollar en serie de potencias con centro en cero. En el caso de $g(z)$ de dos formas diferentes.
# $$ f(z) = cos(z) \Rightarrow cos(z) = \sum_{n=0}^{\infty} (-1)^n\frac{ z^{2n}}{(2n)!} $$
#
#   Primera forma:
# $$ g(z)  = \dfrac{z^2 - cos(z)}{z^3} $$
# $$ g(z) = \dfrac{z^2}{z^3} - \dfrac{cos(z)}{z^3} \Rightarrow g(z) = \dfrac{1}{z} - \dfrac{cos(z)}{z^3} $$
# $$ g(z) = \dfrac{1}{z} - \dfrac{1}{z^3} \sum_{n=0}^{\infty} (-1)^n \frac{z^{2n}}{(2n)!} $$
# $$ g(z) = \dfrac{1}{z} - \sum_{n=0}^{\infty} \dfrac{1}{z^3} (-1)^n\frac{ z^{2n}}{(2n)!} $$
# $$ g(z) = \dfrac{1}{z} - \sum_{n=0}^{\infty} (-1)^n\frac{ z^{2n-3}}{(2n)!} $$
# $$ g(z) = \sum_{n=0}^{\infty} \frac{(2n)!-(-1)^nz^{2n-2}}{(2n)!z} $$
#
#   Segunda forma:
# $$ g(z) = g(z)  = \dfrac{z^2 - cos(z)}{z^3} $$
# $$ g(z) = \dfrac{1}{z} - \sum_{n=0}^{\infty} (-1)^n\frac{ z^{2n-3}}{(2n)!} $$
# $$ g(z) = \dfrac{1}{z} - [\dfrac{1}{z^3} - \dfrac{1}{2z} + \dfrac{z}{4!} - \dfrac{z}{6!} ...] $$
# $$ g(z) = \dfrac{-1}{z^3} + (\dfrac{1}{z} + \dfrac{1}{2z}) - \dfrac{z}{4!} + \dfrac{z}{6!} ... $$
# $$ g(z) = \dfrac{-1}{z^3} + \dfrac{3}{2z} - \dfrac{z}{4!} + \dfrac{z}{6!} ... $$
# $$ g(z) = \sum_{n=-3}^{\infty}a_n z^n $$
# $$ \text{utilizando la ecuacion } a_n = \frac{1}{2\pi j}\displaystyle \oint_{C}\dfrac{f(z)}{(z-z_0)^{n+1}}\,dz $$
# $$ \text{obtendremos cada coeficiente de la serie} $$
#
# * Actividad 3.2. Determinar en ambos casos el orden del cero de la funcion.
# $$ f(z) = cos(z), \text{el orden del cero es cero} $$
# $$ g(z)  = \dfrac{z^2 - cos(z)}{z^3}, \text{tiene un polo de orden 3} $$
#
# * Actividad 3.3. Determinar en ambos casos que tipo de singularidades encuentra.
# $$ f(z) = cos(z), \text{es holomorfa en todo el plano } \mathbb{C} $$
# $$ g(z)  = \dfrac{z^2 - cos(z)}{z^3}, \text{tiene singularidades en z=0} $$
#
# * Actividad 3.4. Calcular el residuo donde corresponda.
# $$ Res(g(z),0) = \dfrac{1}{2!} \lim_{z \to 0} \dfrac{d^{2}}{dz^{2}} [\dfrac{z^2-cos(z)}{z^3}(z)^3]$$
# $$ Res(g(z),0) = \dfrac{1}{2} \lim_{z \to 0} (2+cos(z)) $$
# $$ Res(g(z),0) = \dfrac{1}{2}(2+1) $$
# $$ Res(g(z),0) =\dfrac{3}{2} $$

# %% [markdown]
# # **Ejercicio 4**
# * Ejercicio 4: Considerar la siguiente integral
# $$\mathcal{I} = \displaystyle \oint_{|z^2|=1}\dfrac{sen(5z^2)}{z}\,dz$$
#
# * Marco teorico utilizado:
#   $$f^{(n)}(z_0) = \frac{n!}{2\pi j} \oint_C \frac{f(z)}{(z - z_0)^{n+1}}\, dz \Rightarrow \text{Ecuacion de integracion de Cauchy}$$ <br>
#   $$f(z) = \sum_{n=-\infty}^{\infty} a_n (z - z_0)^n \Rightarrow \operatorname{Res}(f; z_0) = a_{-1}
#  $$ <br>
#    $$\operatorname{Res}(f; z_0) = \lim_{z \to z_0} (z - z_0) f(z) $$<br>
# $$\oint_C f(z)\,dz = 2\pi j \sum_{k=1}^n \operatorname{Res}(f; z_k)$$ <br>
#
#   $$
# \sin(z) = \sum_{n=0}^{\infty} \frac{(-1)^n z^{2n+1}}{(2n+1)!} \Rightarrow\sin(z) = z - \frac{z^3}{3!} + \frac{z^5}{5!} - \frac{z^7}{7!}
#  + \cdots
# $$  <br>
#
#
#   * Actividad 4.1. Usar el mapeo propuesto y realizar una sustitución para cambiar de la variable $\mathcal{Z}$ a la variable $\mathcal{W}$, es decir, obtener una expresión del tipo: $\mathcal{I} = \oint_{|w|=1}\,F(w)\,dw$. <br>
#
#     Considerando: <br>
#     $$\omega = z^2$$ <br>
#     $$z = \sqrt{\omega}$$
#
#     Región de integración:
#     $$|z^2| = 1 \Rightarrow |\omega| = 1 $$ <br>
#     Función integrando:
#     $$F(z) = \frac{sen(5z^2))}{z} \Rightarrow F(\omega) = \frac{sen(5\omega)}{\sqrt{\omega}}$$ <br>
#     Cambio de diferencial:
#     $$z = \sqrt{\omega}$$
#     $$dz = \frac{1}{2\sqrt{\omega}}$$
#   Respuesta:
#     $$\mathcal{I^\prime} = \oint_{|\omega| = 1}\frac{sen(5\omega)}{\sqrt{\omega}} \cdot \frac{1}{2 \sqrt{\omega}} d\omega$$ <br>
#     $$\Rightarrow \mathcal{I^\prime} = \oint_{|\omega| = 1} \frac{sen(5\omega)}{2\omega} d\omega$$
#
#   * Actividad 4.2. Empleando distintos métodos: <br>
#     Evaluar la integral $\mathcal{I}$ empleando la formula generalizada de integración de Cauchy. <br>
#     * Método 1: Fórmula generalizada de integración de Cauchy
#     $$f(z_0) = \frac{1}{2\pi j}\oint_{C} \frac{f(z)}{z}dz$$ <br>
#     $$\Rightarrow \oint_{C} \frac{f(z)}{z}dz = 2\pi j f(z_0)$$
#     Punto de singularidad:
#     $$z_0 = 0, \hspace{15pt} z_o \in |z^2| = 1$$ <br>
#     Análisis:
#     $$f(z) = sen(5z^2) \text{ es holomorfa en todo el plano } \mathbb{C}$$ <br>
#     $$\oint \frac{sen(5z^2)}{z} = 2\pi j sen(5.0) \rightarrow sen(0) = 0$$
#     $$\Rightarrow \oint \frac{sen(5z^2)}{z} = 0 \text{ RTA }$$
#     * Método 2: Teorema del resuido <br>
#     Evaluar la integral $\mathcal{I}$ empleando el teorema del resuido.  <br>
#     *  El teorema del resuido para un polo simple como es nuestro caso nos dice que:
#     $$\oint_C f(z)\,dz = 2\pi j \sum_{k=1}^n \operatorname{Res}(f; z_k)\rightarrow \operatorname{Res}(f; z_0) = \lim_{z \to z_0} (z - z_0) f(z) $$ <br>
#     Donde nuestra funcion es:
#      $$\frac{sen(5z^2)}{z}$$
#     Aplicando el teorema:
#     $$\oint \frac{sen(5z^2)}{z}= 2\pi j\lim_{z \to 0} z \frac{sen(5z^2)}{z} =2\pi j \lim_{z \to 0} sen(5z^2)=2\pi j sen(0)$$ <br>
#     $$ \Rightarrow \oint \frac{sen(5z^2)}{z} = 0 \text{ RTA } $$
#     <br>
#     * Método 3: Usando una serie de potencias centrada en cero <br>
#     Para este metodo expandimos la serie de taylor del Seno centrada en 0 ya que es la serie que conocemos: <br>
#     $$\sin(5z^2) = 5z^2 - \frac{(5z^2)^3}{3!} + \frac{(5z^2)^5}{5!} - \cdots$$
#    <br>
#     y a esta serie la multiplcamos por nuestra singularidad:
#     $$\frac{\sin(5z^2)}{z} = 5z - \frac{125z^5}{6} + \frac{3125z^9}{120} - \cdots$$ <br>
#     sabiendo que:
#     $$ \oint_C f(z)\,dz = 2\pi j \sum_{k=1}^n \operatorname{Res}(f; z_k)\rightarrow \operatorname{Res}(f; z_0) = a_{-1}
#     $$ <br>
#     el desarrollo de serie de nuestra funcion  contiene únicamente potencias positivas de \(z\) por lo que no existe ningun termino \(a_{-1}\) nos queda que:
#     $$\operatorname{Res}(f; z_0)=0 \rightarrow \oint \frac{sen(5z^2)}{z}= 2\pi j 0$$<br>
#     $$ \Rightarrow \oint \frac{sen(5z^2)}{z} = 0 \text{ RTA } $$

# %% [markdown]
# # ***Ejercicio 5.***
#
# ## *Marco teorico utilizado*
#
# $$ \cos(z) = \dfrac{e^{jz} + e^{jz}}{2} $$
#
# $$ e^{x+jy} = e^x \cos(y) + j e^x \sin(y) $$
#
# $$ \cos (-y) = \cos (y) $$
#
# $$ \sin (-y) + -\sin(y) $$
#
# $$ \cosh (z) = \dfrac{e^z + e^{-z}}{2} $$
#
# $$ \sinh (z) = \dfrac{e^z - e^{-z}}{2} $$
#
# $$  \dfrac{\partial u}{\partial x} = \dfrac{\partial v}{\partial y} \quad \wedge \quad \dfrac{\partial u}{\partial y} = -\dfrac{\partial v}{\partial x} \Rightarrow \text{Ecuaciones de Cauchy-Riemann} $$
#
# $$ \dfrac{d}{dz}\sinh(z) = \cosh(z) $$
#
# $$ \dfrac{d}{dz}\cosh(z) = \sinh(z) $$
#
# $$ {e^{j{\pi}}} = -1 $$
#
# $$ \text{pero tambien} \Rightarrow {e^{j({\pi}+2k{\pi})}},  \text{con k} \in \mathbb{Z} $$
#
#
#
# * Ejercicio 5. Considerar la función en variable compleja $f(z) = \cos(jz)$
#  * Actividad 5.1. Defina explícitamente la función $f(z)$ como una combinación lineal de exponenciales.
#    * $$ f(z) = \cos(jz) = \dfrac{e^{j(jz)} + e^{-j(jz)}}{2} = \dfrac{e^{-z} + e^z}{2} $$
#  * Actividad 5.2. Obtener la parte real e imaginaria de la función $f(z) = u(x,y) + j\,v(x,y)$.
#    * $$ f(z) = \dfrac{e^{-z} + e^z}{2} $$
#    $$ e^{-z} = e^{-x} [\cos(-y)+j\sin(-y)] = e^{-x} [\cos(y)-j\sin(y)] $$
#    $$ e^z = e^x [\cos(y)+j\sin(y)] $$
#    $$ \text{Ahora podemos reemplazar con esas 2 resoluciones en la ecuacion anterior.} $$
#    $$ f(z) = \dfrac{{e^{-x}[\cos(y)-j\sin(y)]} + {e^x [\cos(y)+j\sin(y)]}}{2} $$
#    $$ f(z) = \dfrac{[e^{-x}\cos(y)+e^x\cos(y)]+j[-e^{-x}\sin(y)+e^x\sin(y)]}{2} $$
#    $$ f(z) = \dfrac{\cos(y)(e^x + e^{-x})+ j \sin(y)(e^x - e^{-x})}{2} $$
#    $$ f(z) = \cos(y)\dfrac{e^x + e^{-x}}{2} + j \sin(y)\dfrac{e^x - e^{-x}}{2}$$
#    $$ f(z) = \cos(y) \cosh(x) + j \sin(y) \sinh(x) $$
#    $$ u(x,y) = \cos(y)\cosh(x) $$
#    $$ v(x,y) = \sin(y)\sinh(x) $$
#   * Actividad 5.3. Demostrar que la función $f(z)$ es analítica en todo el plano, para ello, mostrar que las funciones $u(x,y)$ y $v(x,y)$ cumplen las ecuaciones de Cauchy-Riemann en todo el plano.
#     * $$ \dfrac{\partial u}{\partial x} = \cos(y)\sinh(x) $$
#       $$ \dfrac{\partial u}{\partial y} = -\sin(y)\cosh(x) $$
#       $$ \dfrac{\partial v}{\partial x} = \sin(y)\cosh(x) $$
#       $$ \dfrac{\partial v}{\partial y} = \cos(y) \sinh(x) $$
#       $$ \cos(y)\sinh(x) = \cos(y)\sinh(x) $$
#       $$ -\sin(y)\cosh(x) = -(\sin(y)\cosh(x)) $$
#       Demostrando que las ecuaciones de Cauchy-Riemann se verifican, demostramos que la funcion es analitica en todo el plano complejo {$\mathbb{C}$}.
#   * Actividad 5.4. Obtener el conjunto infinito de soluciones de la ecuación $f(z) = 0$
#     * $$ f(z) = \dfrac{e^{-z} + e^z}{2} $$
#       $$ \dfrac{e^{-z} + e^z}{2} = 0 $$
#       $$ {e^{-z} + e^z} = 0 $$
#       $$ {e^ze^{-z} + e^ze^z} = 0 $$
#       $$ {e^{2z} + 1} = 0 $$
#       $$ {e^{2z}} = -1 $$
#       $$ {e^{2z}} = {e^{j{\pi}(1+2k)}} $$
#       $$ 2z = j{\pi}(1+2k) $$
#       $$ z = \frac{j{\pi}(1+2k)}{2} $$
#
#  * Actividad 5.5. Evaluar las siguientes integrales:
#   $$\displaystyle\int_{0}^{j\,\pi}{e^{z}f(z)}\,dz;\qquad \displaystyle\oint_{|2z-\pi j|=2}\,\dfrac{e^{z}}{f(z)}\,dz$$
#
#   $$\displaystyle\int_{0}^{j\,\pi}{e^{z}f(z)}\,dz$$
#   * Para la primera integral, utilizamos que:
#
#   $$f(z) = \cos(jz) = \dfrac{e^z + e^{-z}}{2}$$
#   $$$$
#   $$ \int_{0}^{j\pi} e^z f(z)\,dz = \int_{0}^{j\pi} e^z \cdot \dfrac{e^z + e^{-z}}{2} \, dz $$
#   $$$$
#   $$ = \int_{0}^{j\pi} \dfrac{e^{2z} + 1}{2} \, dz $$
#   $$$$
#   $$ = \dfrac{1}{2} \int_{0}^{j\pi} (e^{2z} + 1) \, dz $$
#   $$$$
#   $$ = \dfrac{1}{2} \left[ \int_{0}^{j\pi} e^{2z} \, dz + \int_{0}^{j\pi} 1 \, dz \right] $$
#   $$$$
#   $$ = \dfrac{1}{2} \left[ \dfrac{e^{2z}}{2} \bigg|_{0}^{j\pi} + z \bigg|_{0}^{j\pi} \right] $$
#   $$$$
#   $$ = \dfrac{1}{2} \left[ \dfrac{e^{2j\pi} - 1}{2} + j\pi \right] $$
#  $$$$
#  * sabiendo que:
#   $$ e^{2j\pi} = 1 $$
#   $$$$
#   $$ = \dfrac{1}{2} \left[ \dfrac{1 - 1}{2} + j\pi \right] = \dfrac{j\pi}{2} $$
# $$$$
#   * Para la segunda integral:
#   $$\displaystyle\oint_{|2z-\pi j|=2}\,\dfrac{e^{z}}{f(z)}\,dz$$
# $$$$
#     * $$ \oint_{|2z - \pi j| = 2} \frac{e^z}{f(z)}\,dz = \oint_{|z - \frac{j\pi}{2}| = 1} \frac{e^z}{\frac{e^z + e^{-z}}{2}}\,dz $$
#
#     * $$ = \oint_{|z - \frac{j\pi}{2}| = 1} \frac{2e^z}{e^z + e^{-z}}\,dz = \oint_{|z - \frac{j\pi}{2}| = 1} \frac{2e^{2z}}{e^{2z} + 1}\,dz $$
#
#     * Las singularidades ocurren cuando:
#       $$ e^{2z} + 1 = 0 \Rightarrow e^{2z} = -1 \Rightarrow 2z = j\pi(1 + 2k) \Rightarrow z = \dfrac{j\pi(1 + 2k)}{2} $$
#
#     * Para \( k = 0 \), tenemos \( z_0 = \dfrac{j\pi}{2} \), que está dentro del contorno
#
#     * por lo que podemos aplicar el Teorema del Residuo
#       $$ \text{Res}\left(\frac{2e^{2z}}{e^{2z} + 1}, z_0\right) = \frac{g(z_0)}{h'(z_0)} \quad \text{con} \quad g(z) = 2e^{2z},\quad h(z) = e^{2z} + 1,\quad h'(z) = 2e^{2z} $$
#       $$ \text{Res} = \frac{2e^{2z_0}}{2e^{2z_0}} = 1 $$
#
#     * Por el Teorema del Residuo:
#       $$ \oint_{|z - \frac{j\pi}{2}| = 1} \frac{2e^{2z}}{e^{2z} + 1}\,dz = 2\pi j \cdot \text{Res} = 2\pi j $$

# %% [markdown]
# # ***Ejercicio 6.***
#
# ## *Marco teorico utilizado*
#
#    $
#    e^{j\theta}=\cos(\theta)+j\sin(\theta)
#    $ \\
#    Suponga que $f(z) = \frac{p(z)}{q(z)}$ es una funcion racional, donde el grado de $p(z)$ es n y el grado de $q(z)$ es $m \geq n + 1$. Si $C_R$ es un contorno semicircular $ z = Re^{j\theta}, 0 \leq \theta \leq \pi$ y $\alpha > 0,$ entonces $ \int_{SC_R}f(z)e^{j\theta z}dz \to 0$ cuando $R \to \infty$.
#    \\
#    $
#    \int_{a}^{b}f(x)dx = h [\frac{f(a)}{2} + f(x+1) + f(x+2) + ... +  \frac{f(b)}{2}]
#    $
#
# * Ejercicio 6. Considerar las siguientes integrales
# $$
# I = \int_{-\infty}^{\infty} \frac{x}{x^2 + 2x + 5} e^{j\pi x} \, dx; \quad
# I_1 = \int_{-\infty}^{\infty} \frac{x}{x^2 + 2x + 5} \cos(\pi x) \, dx; \quad
# I_2 = \int_{-\infty}^{\infty} \frac{x}{x^2 + 2x + 5} \sin(\pi x) \, dx
# $$
#  * Actividad 6.1. Encontrar una ecuación que relaciones estas tres integrales, de forma natural.
#    * $$\int_{-\infty}^{\infty} \frac{x}{x^2 + 2x + 5} e^{j\pi x}dx =
#        \int_{-\infty}^{\infty} \frac{x}{x^2 + 2x + 5} [\cos(\pi x)+j\sin(\pi x)]dx $$
#        $$ \int_{-\infty}^{\infty} \frac{x}{x^2 + 2x + 5} e^{j\pi x}dx = \int_{-\infty}^{\infty} \frac{x}{x^2 + 2x + 5} \cos(\pi x) dx + j\frac{x}{x^2 + 2x + 5} \sin(\pi x) dx $$
#        $$ \int_{-\infty}^{\infty} \frac{x}{x^2 + 2x + 5} e^{j\pi x}dx = \int_{-\infty}^{\infty} \frac{x}{x^2 + 2x + 5} \cos(\pi x) dx + $$
#        $$ j\\int_{-\infty}^{\infty} \frac{x}{x^2 + 2x + 5} \sin(\pi x) dx $$
#
#        $$ I = I_1 + j \ I_2 $$
#   * Actividad 6.2. Proponer una curva conceniente C para calcular las integrales propuestas, usando el teorema del residuo y limite al infinito.
#    * Sea
#    $$
#    f(z) = \frac{z}{z^2 + 2z + 5} e^{j\pi z}
#    $$
#    $$
#    \frac{-2 ± \sqrt{-16}}{2} = -1 \pm 2j
#    $$
#    $$
#    z_0 = -1 + 2j ; z_1 = -1 - 2j
#    $$
#    Entonces con esto dicho elegimos estrategicamente una curva cerrada 'C' que sera:
#    * Una semi-circunferencia, con un radio > 3.
#    * Un intervalo [-R, R] sobre el eje x. \\
#    Donde solo el polo $z_0$ va a estar dentro de la curva.
#    $$
#    \oint_{C} \frac{z}{z^2 + 2z + 5} e^{j\pi z} dz = \int_{-R}^{R} \frac{x}{x^2 + 2x + 5} e^{j\pi x} dx +
#                        \int_{SC_R} \frac{z}{z^2 + 2z + 5} e^{j\pi z} dz
#    $$
#    $$
#    \oint_{C} f(z) dz = \int_{-R}^{R} f(x) dx + \int_{SC_R} f(z) dz
#    $$
#    Ahora tomaremos el $ \lim $ cuando ${R \to \infty} $ en ambos lados de la ecuacion.
#    $$
#    \lim_{R \to \infty} \int_{SC_R} f(z) dz = 0
#    $$
#    $$
#    V.P \int_{-\infty}^{\infty} f(x) dx = 2\pi j Res(f, z_0)
#    $$
#    $$
#    Res(f, z_k) = \frac{1}{(n-1)!} \lim_{z \to z_k} \frac{d^{n-1}}{dz^{n-1}}
#    [(z-z_k)f(z)]
#    $$
#    Siendo n el orden del polo, en el caso de $z_0$ es 1. Calculamos el residuo.
#    $$
#    Res(f, z_0) = \frac{1}{0!} \lim_{z \to z_0} \frac{d^0}{dz^0}[(z-z_0)f(z)]
#    $$
#    $$
#    Res(f, z_0) = \lim_{z \to z_0} [(z-z_0) \frac{z}{(z-z_0)(z-z_1)} e^{j\pi z}] = \lim_{z \to z_0}[\frac{z}{(z-z_1)}e^{j\pi z}] = \frac{z_0}{z_0 - z_1} e^{j\pi z}
#    $$
#    $$
#    Res(f,z_0) = \frac{(-1+2j)}{(-1+2j)-(-1-2j)} e^{j\pi (-1+2j)} =
#    \frac{(-1+2j)}{4j}(e^{-j\pi}e^{-2\pi})
#    $$
#    $$
#    Res(f, z_0) = (\frac{1}{2}+j\frac{1}{4})(-e^{-2\pi}) = -\frac{e^{-2\pi}}{2}-
#    j\frac{e^{-2\pi}}{4}
#    $$
#    Ahora podemos resolver la integral.
#    $$
#    V.P \int_{-\infty}^{\infty} f(x) dx = 2\pi j (-\frac{e^{-2\pi}}{2}-
#    j\frac{e^{-2\pi}}{4}) = \frac{\pi e^{-2\pi}}{2} - j\pi e^{-2\pi}
#    $$
#    $$
#    V.P \int_{-\infty}^{\infty} f(x) dx \approx 2,933372183.10^{-3} - j \, 5,866744367.10^{-3}
#    $$

# %%
import math

a = -100000
b = 100000
n = 10000000 #10M

def integrar(func):
  h = (b - a) / n
  total = 0.5 * (func(a) + func(b))
  for i in range(1, n):
    x = a + i * h
    total += func(x)
  return total * h

def f_real(x):
  return (x / (x**2 + 2*x + 5)) * math.cos(math.pi * x)

def f_imag(x):
  return (x / (x**2 + 2*x + 5)) * math.sin(math.pi * x)

def f_exp(x):
  return (x / (x**2 + 2*x + 5) * math.e**(complex(0, math.pi * x)))

parte_real_trig = integrar (f_real)
parte_imag_trig = integrar (f_imag)

resultado_exp = integrar (f_exp)

print(f'Resultado exponencial = {resultado_exp:.2e}')
print(f'Resultado trigonometrico = {parte_real_trig:.2e} {parte_imag_trig:.2e}j')
# Out:
# Resultado exponencial = 2.93e-03-5.87e-03j
# Resultado trigonometrico = 2.93e-03 -5.87e-03j

# %% [markdown]
# ## ***Ejercicio 7***
#
# *Marco teórico utilizado*
#
# * Ejercicio 7: Considere la siguiente integral:
# $$a = \int^{2\pi}_0 \frac{3}{3-2cos(x) + sen(x)}dx$$
#   * Actividad 7.1: Usar la librería Math-Python para graficar el área bajo la curva entre los límites que propone la integral.

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt

def f(x):
  return 3 / (3 - 2 * math.cos(x) + math.sin(x))

xVals = []
yVals = []
n = 200

for i in range(n+1):
  x = (2 * math.pi) * i / n
  xVals.append(x)
  yVals.append(f(x))

df = pd.DataFrame({'x': xVals, 'y': yVals})
colorBajoCurva = df.plot(x='x', y='y', kind='line', legend=False, title='Área bajo f(x)')
colorBajoCurva.fill_between(df['x'], df['y'], 0, where=(df['y'] >= 0), color='skyblue', alpha=0.5)

# %% [markdown]
#   * Actividad 7.2: Empleando una sustitución conveninete en variable compleja, calcular la integral
#       - Sustitución: <br>
# $$z = e^{jx}$$ <br>
# $$cos(x) = \frac{z+z^{-1}}{2}, \hspace{10pt} sen(x) = \frac{z-z^{-1}}{2j}$$  <br>
# $$[0; 2\pi] \rightarrow |z| = 1$$
#       Cambio diferencial: <br>
#         $$\frac{dz}{dx} = \frac{d}{dx} e^{jx}$$ <br>
#         $$\frac{dz}{dx} = je^{jx}, \hspace{5pt} e^{jx} = z$$ <br>
#         $$\frac{dz}{dx} = jz$$ <br>
#         $$dx = \frac{dz}{jz}$$ <br>
#         $$a = \oint_{|z| = 1}\frac{3}{3-2(\frac{z+z^{-1}}{2})+(\frac{z-z^{-1}}{2j})}\frac{dz}{jz}$$
#
#         Simplificación:
#
#         $$f(z) = \frac{3}{3-2(\frac{z+z^{-1}}{2})+(\frac{z-z^{-1}}{2j})}$$ <br>
#         $$f(z) = \frac{2j}{2j}\cdot\frac{3}{3-z+z^{-1}+(\frac{z-z^{-1}}{2j})}$$ <br>
#         $$f(z) = \frac{z}{z}\cdot\frac{6j}{6j-2jz-2jz^{-1}+(z-z^{-1})}$$ <br>
#         $$f(z) = \frac{6jz}{6jz-2jz^2-2j+z²-1}$$ <br>
#         $$f(z) = \frac{6jz}{(1-2j)z^2 + 6jz -(1+2j)}$$ <br>
#         $$a = 6 \oint_{|z| = 1}\frac{1}{(1-2j)z^2 + 6jz -(1+2j)}dz$$ <br>
#
#         Resolución de la integral: <br>
#         Polos (dados por el denominador):
#         $$z = \frac{-6j\pm\sqrt{(6j)^2-4(1-2j)(-1-2j)}}{2(1-2j)}$$ <br>
#         $$z = \frac{-6j\pm\sqrt{(-36-4(-5)}}{2(1-2j)}$$ <br>
#         $$z = \frac{-6j\pm4j}{2(1-2j)}$$ <br>
#         $$z_1 = \frac{2-j}{5}\text{ Cae en |z|=1 }$$
#         $$z_2 = 2-j$$
#         Para un polo simple:
#         $$Res(\frac{6}{P(z)}, z_1) = \frac{6}{P^\prime(z_1)}$$ <br>
#         $$P(z) = (1-2j)z^2+ 6jz - (1+2j)$$ <br>
#         $$P(z)^\prime = 2(1-2j)z+6j$$ <br>
#         $$P(z_1)^\prime = 2(1-2j)(\frac{2-j}{5})+6j$$ <br>
#         $$P(z_1)^\prime = 4j$$ <br>
#         $$\Rightarrow Res(\frac{6}{P(z)}, z_1) = \frac{6}{4j}$$ <br>
#         $$Res(\frac{6}{P(z)}, z_1) = -\frac{3}{2}j$$ <br>
#         Teorema de los residuos: <br>
#         La integral $a$ es igual a: <br>
#         $$\sum_{polos} Res(\frac{6}{P(z)}, z_1) = 2\pi j(-\frac{3}{2}j)$$ <br>
#         $$\sum_{polos} Res(\frac{6}{P(z)}, z_1) = 3\pi $$ <br>

# %% [markdown]
#   * Actividad 7.3: Usar la librería Math-Python para calcular la integral, y con ello, verificar su respuesta.

# %%
import math

def f(x):
  return 3 / (3 - 2*math.cos(x) + math.sin(x))

def trapecio(f, a, b, n):
  h = (b -a) / n
  suma = 0.5 * (f(a) + f(b))
  for k in range(1, n):
    xk = a + k*h
    suma += f(xk)
  return suma * h

a = 0
b = 2 * math.pi

for n in [1000, 5000, 20000, 100000]:
  approx = trapecio(f, a, b, n)
  print(f"n = {n:6d} -> integral ~= {approx:.6f}")
# Out:
# n =   1000 -> integral ~= 9.424778
# n =   5000 -> integral ~= 9.424778
# n =  20000 -> integral ~= 9.424778
# n = 100000 -> integral ~= 9.424778
